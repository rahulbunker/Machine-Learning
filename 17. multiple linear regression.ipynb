# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\ASUS\\OneDrive\\Desktop\\pandas\\Salary_Data.csv")
df.head()
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
df.shape
# Out:
# (30, 3)

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(data=df)
plt.show()

# %%
sns.heatmap(data=df.corr() , annot=True)
plt.show()

# %%
x = df.iloc[:,:-1]
y = df["Salary"]

# %%
x.head(3)
# Out:
#    YearsExperience   Age
# 0              1.1  21.0
# 1              1.3  21.5
# 2              1.5  21.7

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
x.ndim
# Out:
# 2

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# y = m1x1 + m2x2 + c

# %%
lr.score(x_test,y_test)
# Out:
# 0.8852101657216537

# %%
lr.coef_
# Out:
# array([4882.14850701, 2567.51865301])

# %%
lr.intercept_
# Out:
# -20612.691921485297

# %%
x.columns
# Out:
# Index(['YearsExperience', 'Age'], dtype='object')

# %%
# y_pric = 4882.14850701*YearsExperience + 2567.51865301*age - 20612.691921485297

# %%
lr.predict(x_test)
# Out:
# array([118686.60525402,  67497.80208802, 101581.52273219,  74585.69879684,
#         54833.367916  ,  58044.6977654 ])
